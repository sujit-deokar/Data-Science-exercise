# %% [markdown]
# ## Exercise: Problem 2

# %% [markdown]
#         The CUSTOMER dataset contains name and address information for every customer the company has and the unique identifier for the customer is CUSTOMER_NUMBER.  The PURCHASES dataset contains information on the purchases made by customers in the last three months and also contains the CUSTOMER_NUMBER variable.  Show how you would create a dataset containing all the customers that had not made any purchases in the last three months.

# %%
import numpy as np
import pandas as pd
purchase_data = pd.DataFrame(np.random.randint(2,size=(100, 4)), columns=['P1','P2','P3','P4'])
customer_id = pd.DataFrame({'Customer ID': list(range(1,101))})
customer_purchase = customer_id.join(purchase_data)
customer_purchase
# Out:
#     Customer ID  P1  P2  P3  P4
# 0             1   1   1   0   1
# 1             2   0   1   1   0
# 2             3   0   1   1   1
# 3             4   0   0   0   1
# 4             5   1   0   1   0
# 5             6   0   0   0   0
# 6             7   0   0   0   0
# 7             8   0   1   1   1
# 8             9   0   1   0   1
# 9            10   1   0   0   0
# 10           11   0   0   1   1
# 11           12   0   0   0   1
# 12           13   0   1   0   0
# 13           14   0   0   0   0
# 14           15   1   1   0   1
# 15           16   1   1   1   0
# 16           17   0   0   1   1
# 17           18   1   1   1   1
# 18           19   1   1   0   1
# 19           20   1   1   1   0
# 20           21   1   0   0   0
# 21           22   0   0   1   0
# 22           23   1   0   0   0
# 23           24   1   1   1   0
# 24           25   0   1   0   1
# 25           26   1   1   1   1
# 26           27   0   1   1   1
# 27           28   1   0   1   0
# ...

# %% [markdown]
# Purchase_data consist of following:
#
#     Customer_ID: Unique ID of each customer.
#     P1 to P4: products purchased by customer over 3 months.(represented in yes:1 or no:0 values)

# %%
data = pd.read_csv('Seattle_Parks_And_Recreation_Park_Addresses.csv',nrows=100)
info_data = customer_id.join(data[['Name','Address']])

# %% [markdown]
#     Online sample data to load Name and Address from dataset available from site (https://catalog.data.gov/dataset?organization_type=City+Government&res_format=XML&tags=recreation).

# %%
drop_A=info_data[(customer_purchase[['P1','P2','P3','P4']] == 0).all(axis=1)]
drop_A
# Out:
#     Customer ID                          Name  \
# 5             6        32nd Ave W Boat Launch
# 6             7        6th Ave NW Pocket Park
# 13           14         Amy Yee Tennis Center
# 29           30        Beacon Hill Playground
# 30           31                  Beacon Place
# 34           35              Bell Street Park
# 56           57  Burke-Gilman Playground Park
# 76           77         College Street Ravine
# 81           82                 Corliss Place
#
#                              Address
# 5                         32nd Ave W
# 6                    606  NW 76th St
# 13  2000 Martin Luther King Jr Way S
# 29                   1902 13th Ave S
# 30                1110 S Dearborn St
# 34         1st to 5th Ave on Bell St
# 56            5201 Sand Point Way NE
# 76                5050 SW College St
# 81                    2166 N 50th St
